# %% [markdown]
# <a href="https://colab.research.google.com/github/faycal1/IA-Model-Simple-Calculation-Traninig/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras

# %%
import numpy as np

# Input data
x_train = np.array([[1, 1], [1, -1], [1, 1]])
# Output data
y_train = np.array([[2], [0], [1]])

# %%
model = keras.Sequential([
    keras.layers.Dense(1, input_shape=(2,))
])

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
x_test = np.array([[1, 2], [1, -3]])
predictions = model.predict(x_test)
print(predictions)
# Out:
# 1/1 [==============================] - 0s 160ms/step
# [[ 0.6269511]
#  [-3.85352  ]]

# %%
x_test = np.array([[1, 1], [1, -1]])
predictions = model.predict(x_test)
print(predictions)
# Out:
# 1/1 [==============================] - 0s 24ms/step
# [[-0.2691431]
#  [-2.0613315]]

# %%
x_train = np.array([[1, 1], [1, -1], [1, 1], [2, 3], [5, 2], [4, 4], [0, 1], [3, 3], [2, -1], [4, 1]])
# Output data
y_train = np.array([[2], [0], [1], [5], [7], [16], [1], [9], [1], [4]])

# %%
model = keras.Sequential([
    keras.layers.Dense(1, input_shape=(2,))
])

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(x_train, y_train, epochs=1000)

# Test the model
x_test = np.array([[1, 2], [3, 4], [5, 6]])
predictions = model.predict(x_test)
print(predictions)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 1s 625ms/step - loss: 34.9426
# Epoch 2/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 34.8832
# Epoch 3/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 34.8240
# Epoch 4/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 34.7647
# Epoch 5/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 34.7056
# Epoch 6/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 34.6465
# Epoch 7/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 34.5875
# Epoch 8/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 34.5285
# Epoch 9/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 34.4696
# Epoch 10/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 34.4108
# Epoch 11/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 34.3521
# Epoch 12/1000
# ...

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# Input data
x_train = np.array([[1, 1], [1, -1], [1, 1], [2, 3], [5, 2], [4, 4], [0, 1], [3, 3], [2, -1], [4, 1]])
# Output data
y_train = np.array([[2], [0], [1], [5], [7], [16], [1], [9], [1], [4]])

# Build the model
model = keras.Sequential([
    keras.layers.Dense(1, input_shape=(2,))
])

# Compile the model
model.compile(optimizer='rmsprop', loss='mean_squared_error')

# Train the model
model.fit(x_train, y_train, epochs=1000)

# Test the model
x_test = np.array([[1, 2], [3, 4], [5, 6]])
predictions = model.predict(x_test)
print(predictions)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 324ms/step - loss: 36.2930
# Epoch 2/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 36.1015
# Epoch 3/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 35.9631
# Epoch 4/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 35.8476
# Epoch 5/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 35.7452
# Epoch 6/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 35.6517
# Epoch 7/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 35.5644
# Epoch 8/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 35.4818
# Epoch 9/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 35.4029
# Epoch 10/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 35.3269
# Epoch 11/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 35.2533
# Epoch 12/1000
# ...

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# Input data
x_train = np.array([[1, 1], [1, -1], [1, 1], [2, 3], [5, 2], [4, 4], [0, 1], [3, 3], [2, -1], [4, 1]])
# Output data
y_train = np.array([[2], [0], [1], [5], [7], [16], [1], [9], [1], [4]])

# Build the model
model = keras.Sequential([
    keras.layers.Dense(1, input_shape=(2,))
])

# Compile the model with SGD optimizer
model.compile(optimizer='sgd', loss='mean_squared_error')

# Train the model
model.fit(x_train, y_train, epochs=1000)

# Test the model
x_test = np.array([[1, 2], [3, 4], [5, 6]])
predictions = model.predict(x_test)
print(predictions)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 309ms/step - loss: 4.8498
# Epoch 2/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 4.7970
# Epoch 3/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.7482
# Epoch 4/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.7027
# Epoch 5/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.6600
# Epoch 6/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.6199
# Epoch 7/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.5819
# Epoch 8/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.5461
# Epoch 9/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.5122
# Epoch 10/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.4800
# Epoch 11/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.4496
# Epoch 12/1000
# ...

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# Input data
x_train = []
y_train = []
for i in range(1, 10):
    for j in range(1, 10):
        x_train.append([i, j])
        y_train.append([i+j])  # Calculation: addition of the two numbers

# Convert data to NumPy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

# Build the model
model = keras.Sequential([
    keras.layers.Dense(1, input_shape=(2,))
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(x_train, y_train, epochs=1000)

# Test the model
x_test = np.array([[1, 2], [1, -3]])
predictions = model.predict(x_test)
print(predictions)
# Out:
# Epoch 1/1000
# 3/3 [==============================] - 1s 8ms/step - loss: 74.9820
# Epoch 2/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 74.3881
# Epoch 3/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 73.7896
# Epoch 4/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 73.2067
# Epoch 5/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 72.6352
# Epoch 6/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 72.0433
# Epoch 7/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 71.4695
# Epoch 8/1000
# 3/3 [==============================] - 0s 9ms/step - loss: 70.8918
# Epoch 9/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 70.3132
# Epoch 10/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 69.7365
# Epoch 11/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 69.1864
# Epoch 12/1000
# ...

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# Input data
x_train = []
y_train = []
for i in range(1, 10):
    for j in range(1, 10):
        x_train.append([i, j])
        y_train.append([i+j])  # Calculation: addition of the two numbers

# Convert data to NumPy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

# Build the model
model = keras.Sequential([
    keras.layers.Dense(1, input_shape=(2,))
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(x_train, y_train, epochs=1000)

# Test the model
x_test = np.array([[1, 2], [1, -3]])
predictions = model.predict(x_test)
print(predictions)
# Out:
# Epoch 1/1000
# 3/3 [==============================] - 1s 8ms/step - loss: 74.9820
# Epoch 2/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 74.3881
# Epoch 3/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 73.7896
# Epoch 4/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 73.2067
# Epoch 5/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 72.6352
# Epoch 6/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 72.0433
# Epoch 7/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 71.4695
# Epoch 8/1000
# 3/3 [==============================] - 0s 9ms/step - loss: 70.8918
# Epoch 9/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 70.3132
# Epoch 10/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 69.7365
# Epoch 11/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 69.1864
# Epoch 12/1000
# ...

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# Input data
x_train = []
y_train = []
for i in range(1, 10):
    for j in range(1, 10):
        x_train.append([i, j])
        y_train.append([i+j])  # Calculation: addition of the two numbers

# Convert data to NumPy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

# Build the model
model = keras.Sequential([
    keras.layers.Dense(1, input_shape=(2,))
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(x_train, y_train, epochs=1000)

# Test the model
x_test = np.array([[1, 2], [1, -3]])
predictions = model.predict(x_test)
print(predictions)
# Out:
# Epoch 1/1000
# 3/3 [==============================] - 1s 8ms/step - loss: 74.9820
# Epoch 2/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 74.3881
# Epoch 3/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 73.7896
# Epoch 4/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 73.2067
# Epoch 5/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 72.6352
# Epoch 6/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 72.0433
# Epoch 7/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 71.4695
# Epoch 8/1000
# 3/3 [==============================] - 0s 9ms/step - loss: 70.8918
# Epoch 9/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 70.3132
# Epoch 10/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 69.7365
# Epoch 11/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 69.1864
# Epoch 12/1000
# ...

# %%
x_test = np.array([[0, 0], [1, 1]])
predictions = model.predict(x_test)
print(predictions)
# Out:
# 1/1 [==============================] - 0s 25ms/step
# [[0.67209935]
#  [2.5508842 ]]

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# Input data
x_train = []
y_train = []
for i in range(1, 10):
    for j in range(1, 10):
        x_train.append([i, j])
        y_train.append([i+j])  # Calculation: addition of the two numbers

# Convert data to NumPy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

# Build the model
model = keras.Sequential([
    keras.layers.Dense(64, activation='relu', input_shape=(2,)),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(1)
])
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(x_train, y_train, epochs=1000)

# Test the model
x_test = np.array([[1, 2], [3, 4], [5, 6]])
predictions = model.predict(x_test)
print(predictions)
# Out:
# Epoch 1/1000
# 3/3 [==============================] - 1s 11ms/step - loss: 119.9255
# Epoch 2/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 100.8466
# Epoch 3/1000
# 3/3 [==============================] - 0s 8ms/step - loss: 83.4585
# Epoch 4/1000
# 3/3 [==============================] - 0s 9ms/step - loss: 68.8251
# Epoch 5/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 55.4662
# Epoch 6/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 43.5309
# Epoch 7/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 32.7623
# Epoch 8/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 24.0033
# Epoch 9/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 16.4800
# Epoch 10/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 10.5691
# Epoch 11/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 6.1666
# Epoch 12/1000
# ...

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# Input data
x_train = np.array([[1, 1], [1, -1], [1, 1], [2, 3], [5, 2], [4, 4], [0, 1], [3, 3], [2, -1], [4, 1]])
# Output data
y_train = np.array([[2], [0], [1], [5], [7], [16], [1], [9], [1], [4]])

# Build the model
model = keras.Sequential([
    keras.layers.Dense(64, activation='relu', input_shape=(2,)),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Define `predict` as a TensorFlow function
@tf.function
def predict(model, inputs):
    return model(inputs)

# Train the model
model.fit(x_train, y_train, epochs=1000)

# Test the model
x_test = np.array([[1, 2], [3, 4], [5, 6]])
predictions = predict(model, x_test)
print(predictions)

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# Input data
x_train = []
y_train = []
for i in range(1, 10):
    for j in range(1, 10):
        x_train.append([i, j])
        y_train.append([i+j])  # Calculation: addition of the two numbers
        
        if i > 1 and i < 9:  # Additional data generation for numbers 2 to 8
            x_train.append([i, j])
            y_train.append([i+j])  # Calculation: addition of the two numbers


# Convert data to NumPy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

# Build the model
model = keras.Sequential([
    keras.layers.Dense(64, activation='relu', input_shape=(2,)),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(1)
])
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(x_train, y_train, epochs=1000)

# Test the model
x_test = np.array([[1, 2], [3, 4], [5, 6]])
predictions = model.predict(x_test)
print(predictions)

# %%
# Test the model
x_test = np.array([[1, 1], [3, 3], [5, 0], [0,0]])
predictions = model.predict(x_test)
print(predictions)

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# Input data
x_train = []
y_train = []
for i in range(1, 10):
    for j in range(1, 10):
        x_train.append([i, j])
        y_train.append([i+j])  # Calculation: addition of the two numbers
        
        if i > 1 and i < 9:  # Additional data generation for numbers 2 to 8
            x_train.append([i, j])
            y_train.append([i+j])  # Calculation: addition of the two numbers


# Convert data to NumPy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

# Build the model
model = keras.Sequential([
    keras.layers.Dense(64, activation='relu', input_shape=(2,)),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(1)
])
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(x_train, y_train, epochs=1000)

# Test the model
x_test = np.array([[1, 2], [3, 4], [5, 6]])
predictions = model.predict(x_test)
print(predictions)
# Out:
# Epoch 1/1000
# 5/5 [==============================] - 1s 4ms/step - loss: 94.5932
# Epoch 2/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 72.7585
# Epoch 3/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 52.0584
# Epoch 4/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 32.9980
# Epoch 5/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 15.6289
# Epoch 6/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 3.9195
# Epoch 7/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6065
# Epoch 8/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 2.3640
# Epoch 9/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 2.5173
# Epoch 10/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.9413
# Epoch 11/1000
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2542
# Epoch 12/1000
# ...

# %%
x_test = np.array([[1, 0], [3, 1], [5, 5], [9,9] , [0,0]])
predictions = model.predict(x_test)
print(predictions)
# Out:
# 1/1 [==============================] - 0s 26ms/step
# [[1.00838304e+00]
#  [4.00072670e+00]
#  [9.99991417e+00]
#  [1.80006599e+01]
#  [1.07964445e-02]]
